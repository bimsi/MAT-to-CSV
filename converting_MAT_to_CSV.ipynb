# %% [markdown]
# <a href="https://colab.research.google.com/github/bimsi/MAT-to-CSV/blob/main/converting_MAT_to_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scipy pandas

# %%
import scipy.io as sio
import pandas as pd

# %%
from google.colab import drive

# %%
mat_data = drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
mat_data = sio.loadmat('/content/mydrive/MyDrive/Colab Notebooks/682200108031602.mat')

# %%
mat_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Jan 28 11:51:46 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'VAR_1107': array([[(array([[584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
#                 [584],
# ...

# %%
print(mat_data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Jan 28 11:51:46 2014', '__version__': '1.0', '__globals__': [], 'VAR_1107': array([[(array([[584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
#                [584],
# ...

# %%
for key, value in mat_data.items():
    if isinstance(value, np.ndarray) and value.ndim > 1:
        mat_data[key] = value.flatten()  # Flatten multi-dimensional arrays
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c922297f829c> in <cell line: 1>()
#       1 for key, value in mat_data.items():
# ----> 2     if isinstance(value, np.ndarray) and value.ndim > 1:
#       3         mat_data[key] = value.flatten()  # Flatten multi-dimensional arrays
#
# NameError: name 'np' is not defined

# %%
# Filter out metadata variables starting with '__'
data = {k: v for k, v in mat_data.items() if not k.startswith('__')}

# Create a DataFrame
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1cfbbe9f64b0> in <cell line: 5>()
#       3
#       4 # Create a DataFrame
# ----> 5 df = pd.DataFrame(data)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# ...

# %%
print(mat_data.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-7491a65f3ae8> in <cell line: 1>()
# ----> 1 print(mat_data.head())
#
# AttributeError: 'dict' object has no attribute 'head'
